# %%
import pandas as pd
import requests
from time import sleep

# %%
assemblyai_auth_key = "YOUR_API KEY"

# %%
headers = {
    'authorization': assemblyai_auth_key, 
    'content-type': 'application/json',
}

transcription_endpoint = "https://api.assemblyai.com/v2/transcript"

input_url = "https://download.ted.com/products/146256.mp4"

# %%
def post_transcription_request(input_url): 

    json = {"audio_url": input_url, "iab_categories": True}
    
    response = requests.post(transcription_endpoint, json=json, headers=headers)
    transcription_id = response.json()['id']

    return transcription_id

# %%
def get_transcription_result(transcription_id): 

    current_status = "queued"

    endpoint = f"https://api.assemblyai.com/v2/transcript/{transcription_id}"

    while current_status not in ("completed", "unavailable"):
        
        response = requests.get(endpoint, headers=headers)
        current_status = response.json()['status']
        
        if current_status in ("completed", "unavailable"):
            return response.json()
        else:
            sleep(10)

# %%
transcription_id = post_transcription_request(input_url)

results = get_transcription_result(transcription_id)

# %%
results['iab_categories_result']['summary']
# Out:
# {'EventsAndAttractions>PoliticalEvent': 1.0,
#  'NewsAndPolitics>Politics>PoliticalIssues': 0.8536341786384583,
#  'NewsAndPolitics>Politics': 0.8001156449317932,
#  'NewsAndPolitics>Politics>Elections': 0.26783692836761475,
#  'NewsAndPolitics>Crime': 0.2527463436126709,
#  'Home&Garden>HomeImprovement': 0.19234398007392883,
#  'FamilyAndRelationships>Parenting>AdoptionAndFostering': 0.15178827941417694,
#  'NewsAndPolitics>Law': 0.10496598482131958,
#  'Television>RealityTV': 0.08490221947431564,
#  'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare': 0.05182255059480667,
#  'FamilyAndRelationships>Parenting': 0.05133328214287758,
#  'PopCulture>CelebrityScandal': 0.028794826939702034,
#  'NewsAndPolitics>Politics>WarAndConflicts': 0.0171405840665102,
#  'Shopping>GroceryShopping': 0.009660312905907631,
#  'Education>EarlyChildhoodEducation': 0.008355177007615566,
#  'HealthyLiving>FitnessAndExercise>ParticipantSports': 0.006075866520404816,
#  'Television>FactualTV': 0.005588793195784092,
#  'FamilyAndRelationships>SingleLife': 0.005375334527343512,
#  'MedicalHealth>DiseasesAndConditions>ReproductiveHealth': 0.005345528945326805,
#  'Travel>TravelLocations>AfricaTravel': 0.004588071722537279}

# %%
results['iab_categories_result']
# Out:
# {'status': 'success',
#  'results': [{'text': "Listen, I'm worried about our democracy. Nowadays we have leaders who use division itself as a political tool. They downplay or even encourage, in some cases a deadly assault to overturn an election. And a bunch of them are working really hard to make it harder to vote. The retreat from these processes of democracy, ballot access or legislative debate, judicial review, they are worrisome enough. But what's even more concerning to me is the retreat from the purposes of democracy.",
#    'labels': [{'relevance': 0.9263674020767212,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.9063184261322021,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.8999685645103455,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.7793756723403931, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.0007177300867624581, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.00044408583198674023,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0003017672570422292,
#      'label': 'Technology&Computing>Computing>Internet>InternetForBeginners'},
#     {'relevance': 0.0002978320699185133, 'label': 'Science'},
#     {'relevance': 0.0002926281013060361, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0002596167614683509,
#      'label': 'BusinessAndFinance>Industries>MediaIndustry'}],
#    'timestamp': {'start': 4600, 'end': 44974},
#    'sentences_idx_start': 0,
#    'sentences_idx_end': 5},
#   {'text': 'These old fashioned notions of government of, by, and for the people, the rule of law as superior to the rule of any one personality, liberty and justice for all. Covid made it harder to overlook deep disparities among us in health and wealth and education, and deep unfairness in too much of our policing, leaving a lot of Americans questioning whether our national commitment to social and economic justice is real.',
#    'labels': [{'relevance': 0.9407973289489746,
#      'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.9347401857376099,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.8736569881439209, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.653357744216919, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.45880967378616333,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.010411364957690239,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.010277100838720798,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.004557041451334953,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.0023931171745061874,
#      'label': 'BusinessAndFinance>Business>LargeBusiness'},
#     {'relevance': 0.0018659622874110937,
#      'label': 'NewsAndPolitics>Politics>Elections'}],
#    'timestamp': {'start': 45634, 'end': 81134},
#    'sentences_idx_start': 6,
#    'sentences_idx_end': 7},
#   {'text': "For some time now, in the words of one friend of mine, the self evident truth that all people deserve life, liberty, and the pursuit of happiness seems a long way from settled in the american mind. So to me, american democracy, the supposed model of the form, is up for grabs. I'm worried not just as a lawyer or a former public official, but also, and mainly as a patriot.",
#    'labels': [{'relevance': 0.984480082988739,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9819668531417847, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.9638795256614685,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.07674811035394669,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0035789574030786753, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0006552581326104701,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0004017997707705945,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.0003721683460753411,
#      'label': 'Technology&Computing>Computing>Internet>InternetForBeginners'},
#     {'relevance': 0.0002930013579316437, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0002841980312950909,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'}],
#    'timestamp': {'start': 81714, 'end': 115394},
#    'sentences_idx_start': 8,
#    'sentences_idx_end': 10},
#   {'text': "I grew up on the south side of Chicago in a crowded two bedroom tenement with my mother, my sister, my grandparents, and various relatives who came and went. I went to big, overcrowded, under resourced, sometimes violent public schools. And yet my grandmother would never permit us to say we were poor. Just broke, she'd say, because broke is temporary. Now think about it.",
#    'labels': [{'relevance': 0.2245146632194519,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.038402900099754333,
#      'label': 'FamilyAndRelationships>SingleLife'},
#     {'relevance': 0.028179099783301353,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.01868920400738716,
#      'label': 'BusinessAndFinance>Economy>HousingMarket'},
#     {'relevance': 0.016568584367632866,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.00830319244414568, 'label': 'RealEstate>Houses'},
#     {'relevance': 0.003407037816941738, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.002667507389560342, 'label': 'Home&Garden'},
#     {'relevance': 0.002426632447168231, 'label': 'FamilyAndRelationships'},
#     {'relevance': 0.00206333352252841,
#      'label': 'BusinessAndFinance>Economy>JobMarket'}],
#    'timestamp': {'start': 116454, 'end': 144444},
#    'sentences_idx_start': 11,
#    'sentences_idx_end': 15},
#   {'text': "Here is this refugee from the Jim Crow south who still believed in an America where, with hard work, preparation, and faith, both religious and civic, you could lift yourself from your circumstances of birth. I am for her the result and the symbol of her faith in America. So you better believe I'm a patriot. But patriotism for black Americans is tricky. It's tricky to love a country that doesn't always love you back.",
#    'labels': [{'relevance': 0.0248087290674448,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.006276263855397701,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.00329559575766325,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0031532926950603724,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.002548450604081154, 'label': 'MusicAndAudio>GospelMusic'},
#     {'relevance': 0.0015149919781833887,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0013798901345580816, 'label': 'MusicAndAudio>Blues'},
#     {'relevance': 0.0013638428645208478, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.0013593961484730244, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.0011921875411644578, 'label': 'NewsAndPolitics>Politics'}],
#    'timestamp': {'start': 144484, 'end': 180014},
#    'sentences_idx_start': 16,
#    'sentences_idx_end': 20},
#   {'text': 'I think of the black men who set off to fight for freedom in the world wars and then came home to be denied those very freedoms, some of them lynched while wearing their military uniforms. I think of the black laborers who built great public universities whose doors were closed to them. The black voters who elected great public leaders whose policies, like the GI Bill, were closed to them. For a lot of our history, Americans democracy itself has been closed to black people.',
#    'labels': [{'relevance': 0.04750456288456917,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.017657741904258728,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.010158163495361805,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.00851989071816206, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.007602476514875889,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.005877303425222635, 'label': 'MusicAndAudio>Blues'},
#     {'relevance': 0.0029656291007995605, 'label': 'MusicAndAudio>GospelMusic'},
#     {'relevance': 0.002236550208181143,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0015494580147787929,
#      'label': 'MusicAndAudio>R&B/Soul/Funk'},
#     {'relevance': 0.001534256967715919,
#      'label': 'BooksAndLiterature>Biographies'}],
#    'timestamp': {'start': 181394, 'end': 218374},
#    'sentences_idx_start': 21,
#    'sentences_idx_end': 24},
#   {'text': "Lots of grandmothers like mine have grandsons and granddaughters who never had their chance. Still don't. I remember in college a white classmate asked me why, on earth would you want to be black? When I told her I hadn't considered the alternative and never would, she seems startled and confused. I attribute this in part to the fact that I spoke and dressed like a preppy. I get that part.",
#    'labels': [{'relevance': 0.018136469647288322,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.018052563071250916, 'label': 'PopCulture>CelebrityDeaths'},
#     {'relevance': 0.008774317800998688,
#      'label': 'BooksAndLiterature>YoungAdultLiterature'},
#     {'relevance': 0.008564211428165436, 'label': 'FamilyAndRelationships'},
#     {'relevance': 0.006416908465325832, 'label': 'Education>AdultEducation'},
#     {'relevance': 0.004971690941601992, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.003906955011188984,
#      'label': 'BooksAndLiterature>Biographies'},
#     {'relevance': 0.0030149680096656084,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.0017381608486175537,
#      'label': 'MedicalHealth>DiseasesAndConditions>EndocrineAndMetabolicDiseases>Menopause'},
#     {'relevance': 0.0015947956126183271,
#      'label': 'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11'}],
#    'timestamp': {'start': 218754, 'end': 250684},
#    'sentences_idx_start': 25,
#    'sentences_idx_end': 30},
#   {'text': "But mostly I think she was confused because she couldn't imagine why any black person in his or her right mind wouldn't trade places with her. I think it would blow her mind, as it may some of yours. When I say I am also proud to be a patriot. Given our history, being black and patriotic will certainly strike some people as strange, if not absurd.",
#    'labels': [{'relevance': 0.00725537957623601,
#      'label': 'MusicAndAudio>GospelMusic'},
#     {'relevance': 0.0017080348916351795, 'label': 'MusicAndAudio>Blues'},
#     {'relevance': 0.001279763993807137,
#      'label': 'MusicAndAudio>R&B/Soul/Funk'},
#     {'relevance': 0.0008165034814737737,
#      'label': 'BooksAndLiterature>Biographies'},
#     {'relevance': 0.0008064958383329213,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.0007711624493822455,
#      'label': 'PopCulture>CelebrityDeaths'},
#     {'relevance': 0.0006970904069021344, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.0006964824860915542, 'label': 'MusicAndAudio>HipHopMusic'},
#     {'relevance': 0.00042854840285144746,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.00034448844962753356,
#      'label': 'MusicAndAudio>UrbanContemporaryMusic'}],
#    'timestamp': {'start': 251064, 'end': 277394},
#    'sentences_idx_start': 31,
#    'sentences_idx_end': 34},
#   {'text': "I don't know when patriotism turned into, you know, lapel pins and flyovers and silly arguments about pro football players taking a knee. My love of country is about national aspiration. America is the only nation in human history organized not by geography or a common culture or language or religion or even race, but by a handful of civic ideals. And we've come to define those ideals over time and through struggle as equality, opportunity, and fair play. Why? Because that's what makes freedom possible.",
#    'labels': [{'relevance': 0.06785082072019577,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.047816745936870575,
#      'label': 'HealthyLiving>FitnessAndExercise>ParticipantSports'},
#     {'relevance': 0.020236175507307053,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.019423285499215126,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.009949937462806702, 'label': 'Sports'},
#     {'relevance': 0.005948939826339483,
#      'label': 'EventsAndAttractions>SportingEvents'},
#     {'relevance': 0.005176878068596125, 'label': 'Sports>AmericanFootball'},
#     {'relevance': 0.004947706591337919, 'label': 'Sports>CollegeSports'},
#     {'relevance': 0.004785085562616587,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.004023909103125334, 'label': 'Religion&Spirituality'}],
#    'timestamp': {'start': 278854, 'end': 321994},
#    'sentences_idx_start': 35,
#    'sentences_idx_end': 40},
#   {'text': "That's the America my grandmother believed in. That's the America that has made us a magnet to talent from all over the world. That's the America that makes me, and countless other men and women from every race and background a patriot. In a way, the founders, for all their flaws, designed America to be a nation of values as sort of a country with a conscience, and we've struggled with and against that conscience from the start.",
#    'labels': [{'relevance': 0.22629234194755554,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.0708189606666565,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.06539815664291382, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.008682336658239365, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0024373435880988836,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0021372938062995672,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0016775147523730993, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.001136141363531351,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.0009169543045572937, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.0008353568846359849,
#      'label': 'NewsAndPolitics>Politics>Elections'}],
#    'timestamp': {'start': 324274, 'end': 356854},
#    'sentences_idx_start': 41,
#    'sentences_idx_end': 44},
#   {'text': 'But true patriots understand, given that context, that America cannot be great without also being good. So when we cage refugee children to discourage their parents from seeking sanctuary here, true patriots know we cannot be great without being good. When bullets fly in houses of worship or in schools or in nightclubs or in grocery stores, and our leaders choose the slogans of the gun lobby over the lives of innocents, patriots know we cannot be great without being good.',
#    'labels': [{'relevance': 0.034839119762182236,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.034041035920381546, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0208799596875906,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.004792066756635904,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.0034892756957560778, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.0029870974831283092,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.0012145615182816982, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.0011608873028308153,
#      'label': 'Technology&Computing>Computing>InformationAndNetworkSecurity'},
#     {'relevance': 0.0007300662691704929,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0007056180038489401,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'}],
#    'timestamp': {'start': 357714, 'end': 394574},
#    'sentences_idx_start': 45,
#    'sentences_idx_end': 47},
#   {'text': 'When unarmed black and brown citizens are shot down by unaccountable police, when our justice system is not yet consistently just, patriots know we cannot be great without being good.',
#    'labels': [{'relevance': 0.8052085638046265,
#      'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.08560765534639359,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.02583365887403488,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.008583597838878632, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.008151070214807987,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.00259969150647521, 'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.0009298149961978197, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0007009452092461288,
#      'label': 'BusinessAndFinance>Business>LargeBusiness'},
#     {'relevance': 0.0006595001905225217, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.0006316593498922884,
#      'label': 'Sports>HuntingAndShooting'}],
#    'timestamp': {'start': 395434, 'end': 409984},
#    'sentences_idx_start': 48,
#    'sentences_idx_end': 48},
#   {'text': "When the economy moves on and leaves broken lives and broken expectations behind and our leaders just shrug, or when the public schools continue to fail poor children, and when we can always find the money for a weapon system the military doesn't want, but not the money for the healthcare a young family or senior needs, patriots know, or must ask themselves, can we be great without being good?",
#    'labels': [{'relevance': 0.45084622502326965,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.13609860837459564,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.10643445700407028,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.05688862502574921, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.007392317522317171,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.00633844081312418,
#      'label': 'BusinessAndFinance>Industries>HealthcareIndustry'},
#     {'relevance': 0.004700785502791405,
#      'label': 'PersonalFinance>Insurance>HealthInsurance'},
#     {'relevance': 0.0044359671883285046,
#      'label': 'PersonalFinance>FrugalLiving'},
#     {'relevance': 0.0037439544685184956,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.0030702906660735607,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'}],
#    'timestamp': {'start': 410964, 'end': 440654},
#    'sentences_idx_start': 49,
#    'sentences_idx_end': 49},
#   {'text': "And when we choose a power grab over a fair vote, every true patriot knows we cannot be great without being good patriotism demands more than ceremony and sanctimony. It's about more than what you say you believe. It's about living the values of equality, opportunity, and fair play, even when it's inconvenient, even when it gets in the way of partisan advantage, even when it compels us to be mindful of and compassionate towards the lowly, the vulnerable, the different, and the despised.",
#    'labels': [{'relevance': 0.9392442107200623,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.750544011592865,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.7138100862503052,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.5788256525993347, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.003186684101819992,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0008269231184385717, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.00040585341048426926, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.00028792102239094675, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.00023368687834590673,
#      'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.00022439839085564017,
#      'label': 'NewsAndPolitics>InternationalNews'}],
#    'timestamp': {'start': 442354, 'end': 484294},
#    'sentences_idx_start': 50,
#    'sentences_idx_end': 52},
#   {'text': "Because that's what american democracy is for. Of course, we have policies to fix, whether in job growth or education, in immigration or the justice system, or in these processes of democracy itself. But before we can fix our policies, we have to fix our politics. And by that, I am not just talking about better tone, our hyper partisanship, or a willingness to compromise. As important as all of that is, I'm talking about our purpose.",
#    'labels': [{'relevance': 0.9928903579711914,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.9911612272262573,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9871990084648132, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.025693437084555626,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0005006393184885383, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.00030291624716483057, 'label': 'RealEstate>Houses'},
#     {'relevance': 0.00030223195790313184,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.00028782273875549436,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.0002732195134740323,
#      'label': 'Travel>TravelLocations>EuropeTravel'},
#     {'relevance': 0.0002664222556632012,
#      'label': 'BusinessAndFinance>Economy'}],
#    'timestamp': {'start': 484874, 'end': 515304},
#    'sentences_idx_start': 53,
#    'sentences_idx_end': 57},
#   {'text': "Sure, we should debate, and we always do, what role government should play in any of this, in meeting our civic obligations. But let's try for once not to forget in the heat of the debate that social and economic justice was the point from the start. But I think saving our democracy will take more, not just from elected officials or civic leaders or the media, but more from each one of us.",
#    'labels': [{'relevance': 0.9941701889038086,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.993956446647644, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.9917877316474915,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.004816547501832247,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0021135772112756968,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.0011615583207458258, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.001076373620890081, 'label': 'BusinessAndFinance>Economy'},
#     {'relevance': 0.000603953143581748,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.00047933010500855744,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.0004673264629673213, 'label': 'RealEstate>Houses'}],
#    'timestamp': {'start': 515884, 'end': 544994},
#    'sentences_idx_start': 58,
#    'sentences_idx_end': 60},
#   {'text': "And we're going to have to start, I think, by putting our cynicism down. I'm going to give you an example of what I mean. Near the end of my time in office, America faced a crisis not unlike today's, when there were all these unaccompanied children, some as young as three and four years old, who were flooding across the southern border, having fled over thousands of miles from violence in Central America. And then, just like now, the federal authorities were overwhelmed.",
#    'labels': [{'relevance': 0.05000344291329384,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.030952101573348045,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.024240324273705482, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.02032879739999771,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.018185017630457878, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.01749851182103157,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.008364720270037651,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.0035147052258253098,
#      'label': 'Travel>TravelLocations>NorthAmericaTravel'},
#     {'relevance': 0.002630682662129402,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.002563179936259985,
#      'label': 'Travel>TravelLocations>EuropeTravel'}],
#    'timestamp': {'start': 545494, 'end': 578024},
#    'sentences_idx_start': 61,
#    'sentences_idx_end': 64},
#   {'text': 'So President Obama, who was in office at the time, called on a number of states to temporarily shelter and care for some of these children while they were being processed under our laws. Feelings around immigration ran hot then, just like now. Even so, I agreed that our commonwealth would help because sheltering poor children fleeing unspeakable violence was, to me, an act of patriotism. America has given sanctuary to desperate children for more than a century.',
#    'labels': [{'relevance': 0.33077722787857056,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.01875212788581848,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.003201895859092474,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.0015328740701079369,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.001050358870998025,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.0006913692341186106,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0005417128559201956, 'label': 'Travel>TravelType>Camping'},
#     {'relevance': 0.0005161446169950068,
#      'label': 'Travel>TravelLocations>PolarTravel'},
#     {'relevance': 0.0003803530998993665,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.00033826049184426665,
#      'label': 'BusinessAndFinance>Industries>Non-ProfitOrganizations'}],
#    'timestamp': {'start': 578604, 'end': 611304},
#    'sentences_idx_start': 65,
#    'sentences_idx_end': 68},
#   {'text': 'We rescued irish children from famine, russian and ukrainian children from religious persecution, cambodian children from genocide, haitian children from earthquakes, sudanese children from civil war, our own New Orleans children from Hurricane Katrina. Once, in 1939, we turned our backs on jewish children fleeing the nazis. And it remains a blight on our national reputation, as I fear the separation of children in the last administration will be remembered.',
#    'labels': [{'relevance': 0.877464771270752,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.3958105742931366,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.06460115313529968,
#      'label': 'Education>EarlyChildhoodEducation'},
#     {'relevance': 0.03129217401146889,
#      'label': 'FamilyAndRelationships>Parenting>DaycareAndPre-School'},
#     {'relevance': 0.02492254227399826,
#      'label': "HealthyLiving>Children'sHealth"},
#     {'relevance': 0.006162768229842186,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.00542921107262373,
#      'label': 'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11'},
#     {'relevance': 0.005327318795025349,
#      'label': 'Movies>FamilyAndChildrenMovies'},
#     {'relevance': 0.003504802007228136,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.002694361377507448,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'}],
#    'timestamp': {'start': 611844, 'end': 643306},
#    'sentences_idx_start': 69,
#    'sentences_idx_end': 71},
#   {'text': "The point is that our esteem and our power is enhanced when we rescue the desperate and diminished, when we don't still, I'm not naive. I knew my decision would be controversial. And indeed, for that decision, I was called on hate radio and in social media. Everything but a child of God.",
#    'labels': [{'relevance': 0.08244963735342026,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.014275779947638512,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.007985769771039486,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.006124844774603844, 'label': 'NewsAndPolitics'},
#     {'relevance': 0.0051077501848340034,
#      'label': 'Technology&Computing>Computing>Internet>SocialNetworking'},
#     {'relevance': 0.003716671373695135,
#      'label': 'BusinessAndFinance>Industries>Non-ProfitOrganizations'},
#     {'relevance': 0.003026918275281787,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.0023512733168900013,
#      'label': 'BooksAndLiterature>Biographies'},
#     {'relevance': 0.0021811414044350386,
#      'label': 'Hobbies&Interests>ContentProduction>FreelanceWriting'},
#     {'relevance': 0.0020744253415614367,
#      'label': 'MedicalHealth>DiseasesAndConditions>Injuries>FirstAid'}],
#    'timestamp': {'start': 643490, 'end': 662134},
#    'sentences_idx_start': 72,
#    'sentences_idx_end': 75},
#   {'text': "A couple of days after I announced my decision on an unusually quiet Saturday morning, my wife Diane gave me a list of stuff to go get at the Home Depot, proving for some of you who know her that there is no office high enough that excuses you from one of her honey do lists. It was early in the day, and I thought I'd just slip out quickly on my own without bothering my security detail. What harm could come of that, right?",
#    'labels': [{'relevance': 0.9895914196968079,
#      'label': 'Home&Garden>HomeImprovement'},
#     {'relevance': 0.021951040253043175, 'label': 'Home&Garden'},
#     {'relevance': 0.012838256545364857, 'label': 'Home&Garden>HomeAppliances'},
#     {'relevance': 0.012333271093666553, 'label': 'RealEstate>Houses'},
#     {'relevance': 0.007527640555053949, 'label': 'Travel>TravelType>Camping'},
#     {'relevance': 0.006297559943050146,
#      'label': 'Home&Garden>Remodeling&Construction'},
#     {'relevance': 0.004945462569594383,
#      'label': 'Home&Garden>InteriorDecorating'},
#     {'relevance': 0.0032909316942095757, 'label': 'Home&Garden>SmartHome'},
#     {'relevance': 0.002254783408716321, 'label': 'PopCulture>CelebrityHomes'},
#     {'relevance': 0.0020571767818182707,
#      'label': 'Shopping>HouseholdSupplies'}],
#    'timestamp': {'start': 663434, 'end': 690664},
#    'sentences_idx_start': 76,
#    'sentences_idx_end': 78},
#   {'text': "I knew exactly where I was going and where to find everything on my list. So I set off in the truck in a t shirt and jeans and flip flops, dark glasses and a baseball cap, and it didn't matter. I was outed by the manager in the very first aisle. Good morning, governor. Welcome to the Home Depot. How can I help you? I encountered a man in the checkout line who was red hot mad.",
#    'labels': [{'relevance': 0.6369667649269104,
#      'label': 'Home&Garden>HomeImprovement'},
#     {'relevance': 0.06394369155168533, 'label': 'Shopping>GroceryShopping'},
#     {'relevance': 0.014701540581882, 'label': 'Home&Garden>HomeAppliances'},
#     {'relevance': 0.01439235731959343, 'label': 'Shopping'},
#     {'relevance': 0.005576354451477528, 'label': 'Shopping>HouseholdSupplies'},
#     {'relevance': 0.002185215475037694,
#      'label': 'EventsAndAttractions>Malls&ShoppingCenters'},
#     {'relevance': 0.0012857700930908322,
#      'label': 'Automotive>AutoBuyingAndSelling'},
#     {'relevance': 0.0011276529403403401, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.0010915606981143355,
#      'label': 'Home&Garden>Remodeling&Construction'},
#     {'relevance': 0.000948792090639472, 'label': 'PopCulture>CelebrityHomes'}],
#    'timestamp': {'start': 691324, 'end': 717484},
#    'sentences_idx_start': 79,
#    'sentences_idx_end': 85},
#   {'text': "You know, not hostile or threatening, really angry and loud. And he let me have it. Governor said, I couldn't disagree with you more about your decision. He said, my own wife is an immigrant. She came here legally. That's the way it ought to be. And I just want you to know I think you're wrong. Now, in that circumstance, there was no point in trying to engage with him about how being a refugee is legal under american law.",
#    'labels': [{'relevance': 0.007801915984600782,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.003465627785772085,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.0021958076395094395,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.0019295774400234222,
#      'label': 'FamilyAndRelationships>MarriageAndCivilUnions'},
#     {'relevance': 0.001582818222232163,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0015717691276222467, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0005313108558766544,
#      'label': 'PersonalFinance>PersonalTaxes'},
#     {'relevance': 0.0004846076772082597, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0004384192288853228,
#      'label': 'Travel>TravelLocations>AustraliaAndOceaniaTravel'},
#     {'relevance': 0.00029245964833535254,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'}],
#    'timestamp': {'start': 717904, 'end': 745326},
#    'sentences_idx_start': 86,
#    'sentences_idx_end': 93},
#   {'text': "I just thanked him for his feedback. But everybody in the checkout line and in that area of the story knew who was mad at whom and what he was mad about. Now, I had six other encounters in the store on the same subject. And in every one of those, someone came up and whispered, governor, you're doing the right thing. Governor, thanks for looking out for those kids. Governor, I'm with you.",
#    'labels': [{'relevance': 0.019638748839497566,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.01691087894141674, 'label': 'Shopping>GroceryShopping'},
#     {'relevance': 0.0044114659540355206, 'label': 'NewsAndPolitics'},
#     {'relevance': 0.0041358391754329205, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.003130784025415778, 'label': 'Shopping'},
#     {'relevance': 0.002186911879107356,
#      'label': 'BusinessAndFinance>Business>ConsumerIssues'},
#     {'relevance': 0.002142125740647316, 'label': 'Education>HomeworkAndStudy'},
#     {'relevance': 0.001727878930978477,
#      'label': 'MusicAndAudio>TalkRadio>EducationalRadio'},
#     {'relevance': 0.001669983728788793,
#      'label': 'Education>EarlyChildhoodEducation'},
#     {'relevance': 0.0012972288532182574,
#      'label': 'BusinessAndFinance>Business>ConsumerIssues>Recalls'}],
#    'timestamp': {'start': 745510, 'end': 775634},
#    'sentences_idx_start': 94,
#    'sentences_idx_end': 99},
#   {'text': "The calls to the office were two and three to one in favor of sheltering those children. And when I reflect on that, I think to myself, when did we learn to shout our anger and to whisper our kindness? It's completely upside down. I don't know if that's the reality tv culture we live in or what, but it's too totally backwards. It's time we learned again to shout kindness, to shout compassion, to shout justice.",
#    'labels': [{'relevance': 0.7151538133621216,
#      'label': 'Television>RealityTV'},
#     {'relevance': 0.12503373622894287, 'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.045528706163167953, 'label': 'Television>FactualTV'},
#     {'relevance': 0.043686337769031525,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.015613073483109474,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.010187249630689621,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.006559527944773436,
#      'label': 'PopCulture>CelebrityFamilies'},
#     {'relevance': 0.005955815315246582, 'label': "Television>Children'sTV"},
#     {'relevance': 0.004006463102996349,
#      'label': 'FamilyAndRelationships>SingleLife'},
#     {'relevance': 0.003118121065199375,
#      'label': 'PopCulture>CelebrityRelationships'}],
#    'timestamp': {'start': 776414, 'end': 810768},
#    'sentences_idx_start': 100,
#    'sentences_idx_end': 104},
#   {'text': "That's the purpose of american democracy and the source of our greatness. Blessedly, we're starting to see more and more expressions of this kind of thing across this country. More and more people coming off the sidelines, overcoming their cynicism and fatalism and standing up for America at her generous and optimistic best. From women who are demanding to be treated with the respect and decency everyone deserves. From survivors of domestic violence and abuse, demanding to be seen and heard and believed.",
#    'labels': [{'relevance': 0.9379892945289612,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9372739791870117,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.6850988864898682, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.14115694165229797,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0074823410250246525, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.006807456724345684,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.004101863130927086,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.003241937840357423,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.0017190432408824563, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0014939542161300778,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'}],
#    'timestamp': {'start': 810936, 'end': 848754},
#    'sentences_idx_start': 105,
#    'sentences_idx_end': 109},
#   {'text': "From black and brown people who are demanding consistent professionalism and the presumption of innocence. From police. From students who are demanding we choose their lives and safety over the proliferation of military weapons in civilian hands. From all those lawyers who showed up at polling places in 2020 or at airports after the so called muslim ban, demanding respect for the rule of law. Black lives matter. Time's up. Black girl magic. Occupy Wall street families belong together. At any given time, on any given issue.",
#    'labels': [{'relevance': 0.31079885363578796,
#      'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.04614873602986336,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.013620834797620773,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0106804883107543,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.00880837719887495,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.007642561104148626,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.005074284505099058, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.0037675180938094854, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.0030356755014508963,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.002139891730621457,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'}],
#    'timestamp': {'start': 849374, 'end': 890984},
#    'sentences_idx_start': 110,
#    'sentences_idx_end': 118},
#   {'text': 'They may make any one of us uncomfortable, but they have taken to the legislatures, to the ballot boxes, to the courtrooms, and peacefully to the streets to lay claim to their democracy, its purpose as well as its processes, and ultimately, to affirm the american conscience. They are shouting kindness. If american style democracy is to have a chance, more of us had better put our own cynicism down, summon up our own patriotism and join them. Thank you very much.',
#    'labels': [{'relevance': 0.9637465476989746,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.9558345079421997,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9425167441368103, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.147858127951622,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0004171467153355479, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0002820066292770207,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.00019903674547094852,
#      'label': 'Technology&Computing>Computing>Internet>InternetForBeginners'},
#     {'relevance': 0.00017591306823305786,
#      'label': 'Automotive>AutoBodyStyles>Microcar'},
#     {'relevance': 0.00017366796964779496,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.00014407839626073837,
#      'label': 'Hobbies&Interests>GamesAndPuzzles>RoleplayingGames'}],
#    'timestamp': {'start': 891444, 'end': 928734},
#    'sentences_idx_start': 119,
#    'sentences_idx_end': 122}],
#  'summary': {'EventsAndAttractions>PoliticalEvent': 1.0,
#   'NewsAndPolitics>Politics>PoliticalIssues': 0.8536341786384583,
#   'NewsAndPolitics>Politics': 0.8001156449317932,
#   'NewsAndPolitics>Politics>Elections': 0.26783692836761475,
#   'NewsAndPolitics>Crime': 0.2527463436126709,
#   'Home&Garden>HomeImprovement': 0.19234398007392883,
#   'FamilyAndRelationships>Parenting>AdoptionAndFostering': 0.15178827941417694,
#   'NewsAndPolitics>Law': 0.10496598482131958,
#   'Television>RealityTV': 0.08490221947431564,
#   'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare': 0.05182255059480667,
#   'FamilyAndRelationships>Parenting': 0.05133328214287758,
#   'PopCulture>CelebrityScandal': 0.028794826939702034,
#   'NewsAndPolitics>Politics>WarAndConflicts': 0.0171405840665102,
#   'Shopping>GroceryShopping': 0.009660312905907631,
#   'Education>EarlyChildhoodEducation': 0.008355177007615566,
#   'HealthyLiving>FitnessAndExercise>ParticipantSports': 0.006075866520404816,
#   'Television>FactualTV': 0.005588793195784092,
#   'FamilyAndRelationships>SingleLife': 0.005375334527343512,
#   'MedicalHealth>DiseasesAndConditions>ReproductiveHealth': 0.005345528945326805,
#   'Travel>TravelLocations>AfricaTravel': 0.004588071722537279}}

# %%
results['iab_categories_result']
# Out:
# {'status': 'success',
#  'results': [{'text': "Listen, I'm worried about our democracy. Nowadays we have leaders who use division itself as a political tool. They downplay or even encourage, in some cases a deadly assault to overturn an election. And a bunch of them are working really hard to make it harder to vote. The retreat from these processes of democracy, ballot access or legislative debate, judicial review, they are worrisome enough. But what's even more concerning to me is the retreat from the purposes of democracy.",
#    'labels': [{'relevance': 0.9263674020767212,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.9063184261322021,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.8999685645103455,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.7793756723403931, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.0007177300867624581, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.00044408583198674023,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0003017672570422292,
#      'label': 'Technology&Computing>Computing>Internet>InternetForBeginners'},
#     {'relevance': 0.0002978320699185133, 'label': 'Science'},
#     {'relevance': 0.0002926281013060361, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0002596167614683509,
#      'label': 'BusinessAndFinance>Industries>MediaIndustry'}],
#    'timestamp': {'start': 4600, 'end': 44974},
#    'sentences_idx_start': 0,
#    'sentences_idx_end': 5},
#   {'text': 'These old fashioned notions of government of, by, and for the people, the rule of law as superior to the rule of any one personality, liberty and justice for all. Covid made it harder to overlook deep disparities among us in health and wealth and education, and deep unfairness in too much of our policing, leaving a lot of Americans questioning whether our national commitment to social and economic justice is real.',
#    'labels': [{'relevance': 0.9407973289489746,
#      'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.9347401857376099,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.8736569881439209, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.653357744216919, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.45880967378616333,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.010411364957690239,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.010277100838720798,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.004557041451334953,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.0023931171745061874,
#      'label': 'BusinessAndFinance>Business>LargeBusiness'},
#     {'relevance': 0.0018659622874110937,
#      'label': 'NewsAndPolitics>Politics>Elections'}],
#    'timestamp': {'start': 45634, 'end': 81134},
#    'sentences_idx_start': 6,
#    'sentences_idx_end': 7},
#   {'text': "For some time now, in the words of one friend of mine, the self evident truth that all people deserve life, liberty, and the pursuit of happiness seems a long way from settled in the american mind. So to me, american democracy, the supposed model of the form, is up for grabs. I'm worried not just as a lawyer or a former public official, but also, and mainly as a patriot.",
#    'labels': [{'relevance': 0.984480082988739,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9819668531417847, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.9638795256614685,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.07674811035394669,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0035789574030786753, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0006552581326104701,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0004017997707705945,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.0003721683460753411,
#      'label': 'Technology&Computing>Computing>Internet>InternetForBeginners'},
#     {'relevance': 0.0002930013579316437, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0002841980312950909,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'}],
#    'timestamp': {'start': 81714, 'end': 115394},
#    'sentences_idx_start': 8,
#    'sentences_idx_end': 10},
#   {'text': "I grew up on the south side of Chicago in a crowded two bedroom tenement with my mother, my sister, my grandparents, and various relatives who came and went. I went to big, overcrowded, under resourced, sometimes violent public schools. And yet my grandmother would never permit us to say we were poor. Just broke, she'd say, because broke is temporary. Now think about it.",
#    'labels': [{'relevance': 0.2245146632194519,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.038402900099754333,
#      'label': 'FamilyAndRelationships>SingleLife'},
#     {'relevance': 0.028179099783301353,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.01868920400738716,
#      'label': 'BusinessAndFinance>Economy>HousingMarket'},
#     {'relevance': 0.016568584367632866,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.00830319244414568, 'label': 'RealEstate>Houses'},
#     {'relevance': 0.003407037816941738, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.002667507389560342, 'label': 'Home&Garden'},
#     {'relevance': 0.002426632447168231, 'label': 'FamilyAndRelationships'},
#     {'relevance': 0.00206333352252841,
#      'label': 'BusinessAndFinance>Economy>JobMarket'}],
#    'timestamp': {'start': 116454, 'end': 144444},
#    'sentences_idx_start': 11,
#    'sentences_idx_end': 15},
#   {'text': "Here is this refugee from the Jim Crow south who still believed in an America where, with hard work, preparation, and faith, both religious and civic, you could lift yourself from your circumstances of birth. I am for her the result and the symbol of her faith in America. So you better believe I'm a patriot. But patriotism for black Americans is tricky. It's tricky to love a country that doesn't always love you back.",
#    'labels': [{'relevance': 0.0248087290674448,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.006276263855397701,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.00329559575766325,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0031532926950603724,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.002548450604081154, 'label': 'MusicAndAudio>GospelMusic'},
#     {'relevance': 0.0015149919781833887,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0013798901345580816, 'label': 'MusicAndAudio>Blues'},
#     {'relevance': 0.0013638428645208478, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.0013593961484730244, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.0011921875411644578, 'label': 'NewsAndPolitics>Politics'}],
#    'timestamp': {'start': 144484, 'end': 180014},
#    'sentences_idx_start': 16,
#    'sentences_idx_end': 20},
#   {'text': 'I think of the black men who set off to fight for freedom in the world wars and then came home to be denied those very freedoms, some of them lynched while wearing their military uniforms. I think of the black laborers who built great public universities whose doors were closed to them. The black voters who elected great public leaders whose policies, like the GI Bill, were closed to them. For a lot of our history, Americans democracy itself has been closed to black people.',
#    'labels': [{'relevance': 0.04750456288456917,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.017657741904258728,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.010158163495361805,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.00851989071816206, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.007602476514875889,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.005877303425222635, 'label': 'MusicAndAudio>Blues'},
#     {'relevance': 0.0029656291007995605, 'label': 'MusicAndAudio>GospelMusic'},
#     {'relevance': 0.002236550208181143,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0015494580147787929,
#      'label': 'MusicAndAudio>R&B/Soul/Funk'},
#     {'relevance': 0.001534256967715919,
#      'label': 'BooksAndLiterature>Biographies'}],
#    'timestamp': {'start': 181394, 'end': 218374},
#    'sentences_idx_start': 21,
#    'sentences_idx_end': 24},
#   {'text': "Lots of grandmothers like mine have grandsons and granddaughters who never had their chance. Still don't. I remember in college a white classmate asked me why, on earth would you want to be black? When I told her I hadn't considered the alternative and never would, she seems startled and confused. I attribute this in part to the fact that I spoke and dressed like a preppy. I get that part.",
#    'labels': [{'relevance': 0.018136469647288322,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.018052563071250916, 'label': 'PopCulture>CelebrityDeaths'},
#     {'relevance': 0.008774317800998688,
#      'label': 'BooksAndLiterature>YoungAdultLiterature'},
#     {'relevance': 0.008564211428165436, 'label': 'FamilyAndRelationships'},
#     {'relevance': 0.006416908465325832, 'label': 'Education>AdultEducation'},
#     {'relevance': 0.004971690941601992, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.003906955011188984,
#      'label': 'BooksAndLiterature>Biographies'},
#     {'relevance': 0.0030149680096656084,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.0017381608486175537,
#      'label': 'MedicalHealth>DiseasesAndConditions>EndocrineAndMetabolicDiseases>Menopause'},
#     {'relevance': 0.0015947956126183271,
#      'label': 'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11'}],
#    'timestamp': {'start': 218754, 'end': 250684},
#    'sentences_idx_start': 25,
#    'sentences_idx_end': 30},
#   {'text': "But mostly I think she was confused because she couldn't imagine why any black person in his or her right mind wouldn't trade places with her. I think it would blow her mind, as it may some of yours. When I say I am also proud to be a patriot. Given our history, being black and patriotic will certainly strike some people as strange, if not absurd.",
#    'labels': [{'relevance': 0.00725537957623601,
#      'label': 'MusicAndAudio>GospelMusic'},
#     {'relevance': 0.0017080348916351795, 'label': 'MusicAndAudio>Blues'},
#     {'relevance': 0.001279763993807137,
#      'label': 'MusicAndAudio>R&B/Soul/Funk'},
#     {'relevance': 0.0008165034814737737,
#      'label': 'BooksAndLiterature>Biographies'},
#     {'relevance': 0.0008064958383329213,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.0007711624493822455,
#      'label': 'PopCulture>CelebrityDeaths'},
#     {'relevance': 0.0006970904069021344, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.0006964824860915542, 'label': 'MusicAndAudio>HipHopMusic'},
#     {'relevance': 0.00042854840285144746,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.00034448844962753356,
#      'label': 'MusicAndAudio>UrbanContemporaryMusic'}],
#    'timestamp': {'start': 251064, 'end': 277394},
#    'sentences_idx_start': 31,
#    'sentences_idx_end': 34},
#   {'text': "I don't know when patriotism turned into, you know, lapel pins and flyovers and silly arguments about pro football players taking a knee. My love of country is about national aspiration. America is the only nation in human history organized not by geography or a common culture or language or religion or even race, but by a handful of civic ideals. And we've come to define those ideals over time and through struggle as equality, opportunity, and fair play. Why? Because that's what makes freedom possible.",
#    'labels': [{'relevance': 0.06785082072019577,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.047816745936870575,
#      'label': 'HealthyLiving>FitnessAndExercise>ParticipantSports'},
#     {'relevance': 0.020236175507307053,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.019423285499215126,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.009949937462806702, 'label': 'Sports'},
#     {'relevance': 0.005948939826339483,
#      'label': 'EventsAndAttractions>SportingEvents'},
#     {'relevance': 0.005176878068596125, 'label': 'Sports>AmericanFootball'},
#     {'relevance': 0.004947706591337919, 'label': 'Sports>CollegeSports'},
#     {'relevance': 0.004785085562616587,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.004023909103125334, 'label': 'Religion&Spirituality'}],
#    'timestamp': {'start': 278854, 'end': 321994},
#    'sentences_idx_start': 35,
#    'sentences_idx_end': 40},
#   {'text': "That's the America my grandmother believed in. That's the America that has made us a magnet to talent from all over the world. That's the America that makes me, and countless other men and women from every race and background a patriot. In a way, the founders, for all their flaws, designed America to be a nation of values as sort of a country with a conscience, and we've struggled with and against that conscience from the start.",
#    'labels': [{'relevance': 0.22629234194755554,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.0708189606666565,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.06539815664291382, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.008682336658239365, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0024373435880988836,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0021372938062995672,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0016775147523730993, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.001136141363531351,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.0009169543045572937, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.0008353568846359849,
#      'label': 'NewsAndPolitics>Politics>Elections'}],
#    'timestamp': {'start': 324274, 'end': 356854},
#    'sentences_idx_start': 41,
#    'sentences_idx_end': 44},
#   {'text': 'But true patriots understand, given that context, that America cannot be great without also being good. So when we cage refugee children to discourage their parents from seeking sanctuary here, true patriots know we cannot be great without being good. When bullets fly in houses of worship or in schools or in nightclubs or in grocery stores, and our leaders choose the slogans of the gun lobby over the lives of innocents, patriots know we cannot be great without being good.',
#    'labels': [{'relevance': 0.034839119762182236,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.034041035920381546, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0208799596875906,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.004792066756635904,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.0034892756957560778, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.0029870974831283092,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.0012145615182816982, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.0011608873028308153,
#      'label': 'Technology&Computing>Computing>InformationAndNetworkSecurity'},
#     {'relevance': 0.0007300662691704929,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0007056180038489401,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'}],
#    'timestamp': {'start': 357714, 'end': 394574},
#    'sentences_idx_start': 45,
#    'sentences_idx_end': 47},
#   {'text': 'When unarmed black and brown citizens are shot down by unaccountable police, when our justice system is not yet consistently just, patriots know we cannot be great without being good.',
#    'labels': [{'relevance': 0.8052085638046265,
#      'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.08560765534639359,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.02583365887403488,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.008583597838878632, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.008151070214807987,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.00259969150647521, 'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.0009298149961978197, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0007009452092461288,
#      'label': 'BusinessAndFinance>Business>LargeBusiness'},
#     {'relevance': 0.0006595001905225217, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.0006316593498922884,
#      'label': 'Sports>HuntingAndShooting'}],
#    'timestamp': {'start': 395434, 'end': 409984},
#    'sentences_idx_start': 48,
#    'sentences_idx_end': 48},
#   {'text': "When the economy moves on and leaves broken lives and broken expectations behind and our leaders just shrug, or when the public schools continue to fail poor children, and when we can always find the money for a weapon system the military doesn't want, but not the money for the healthcare a young family or senior needs, patriots know, or must ask themselves, can we be great without being good?",
#    'labels': [{'relevance': 0.45084622502326965,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.13609860837459564,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.10643445700407028,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.05688862502574921, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.007392317522317171,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.00633844081312418,
#      'label': 'BusinessAndFinance>Industries>HealthcareIndustry'},
#     {'relevance': 0.004700785502791405,
#      'label': 'PersonalFinance>Insurance>HealthInsurance'},
#     {'relevance': 0.0044359671883285046,
#      'label': 'PersonalFinance>FrugalLiving'},
#     {'relevance': 0.0037439544685184956,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.0030702906660735607,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'}],
#    'timestamp': {'start': 410964, 'end': 440654},
#    'sentences_idx_start': 49,
#    'sentences_idx_end': 49},
#   {'text': "And when we choose a power grab over a fair vote, every true patriot knows we cannot be great without being good patriotism demands more than ceremony and sanctimony. It's about more than what you say you believe. It's about living the values of equality, opportunity, and fair play, even when it's inconvenient, even when it gets in the way of partisan advantage, even when it compels us to be mindful of and compassionate towards the lowly, the vulnerable, the different, and the despised.",
#    'labels': [{'relevance': 0.9392442107200623,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.750544011592865,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.7138100862503052,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.5788256525993347, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.003186684101819992,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0008269231184385717, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.00040585341048426926, 'label': 'Religion&Spirituality'},
#     {'relevance': 0.00028792102239094675, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.00023368687834590673,
#      'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.00022439839085564017,
#      'label': 'NewsAndPolitics>InternationalNews'}],
#    'timestamp': {'start': 442354, 'end': 484294},
#    'sentences_idx_start': 50,
#    'sentences_idx_end': 52},
#   {'text': "Because that's what american democracy is for. Of course, we have policies to fix, whether in job growth or education, in immigration or the justice system, or in these processes of democracy itself. But before we can fix our policies, we have to fix our politics. And by that, I am not just talking about better tone, our hyper partisanship, or a willingness to compromise. As important as all of that is, I'm talking about our purpose.",
#    'labels': [{'relevance': 0.9928903579711914,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.9911612272262573,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9871990084648132, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.025693437084555626,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0005006393184885383, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.00030291624716483057, 'label': 'RealEstate>Houses'},
#     {'relevance': 0.00030223195790313184,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.00028782273875549436,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.0002732195134740323,
#      'label': 'Travel>TravelLocations>EuropeTravel'},
#     {'relevance': 0.0002664222556632012,
#      'label': 'BusinessAndFinance>Economy'}],
#    'timestamp': {'start': 484874, 'end': 515304},
#    'sentences_idx_start': 53,
#    'sentences_idx_end': 57},
#   {'text': "Sure, we should debate, and we always do, what role government should play in any of this, in meeting our civic obligations. But let's try for once not to forget in the heat of the debate that social and economic justice was the point from the start. But I think saving our democracy will take more, not just from elected officials or civic leaders or the media, but more from each one of us.",
#    'labels': [{'relevance': 0.9941701889038086,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.993956446647644, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.9917877316474915,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.004816547501832247,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0021135772112756968,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.0011615583207458258, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.001076373620890081, 'label': 'BusinessAndFinance>Economy'},
#     {'relevance': 0.000603953143581748,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.00047933010500855744,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.0004673264629673213, 'label': 'RealEstate>Houses'}],
#    'timestamp': {'start': 515884, 'end': 544994},
#    'sentences_idx_start': 58,
#    'sentences_idx_end': 60},
#   {'text': "And we're going to have to start, I think, by putting our cynicism down. I'm going to give you an example of what I mean. Near the end of my time in office, America faced a crisis not unlike today's, when there were all these unaccompanied children, some as young as three and four years old, who were flooding across the southern border, having fled over thousands of miles from violence in Central America. And then, just like now, the federal authorities were overwhelmed.",
#    'labels': [{'relevance': 0.05000344291329384,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.030952101573348045,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.024240324273705482, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.02032879739999771,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.018185017630457878, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.01749851182103157,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.008364720270037651,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.0035147052258253098,
#      'label': 'Travel>TravelLocations>NorthAmericaTravel'},
#     {'relevance': 0.002630682662129402,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.002563179936259985,
#      'label': 'Travel>TravelLocations>EuropeTravel'}],
#    'timestamp': {'start': 545494, 'end': 578024},
#    'sentences_idx_start': 61,
#    'sentences_idx_end': 64},
#   {'text': 'So President Obama, who was in office at the time, called on a number of states to temporarily shelter and care for some of these children while they were being processed under our laws. Feelings around immigration ran hot then, just like now. Even so, I agreed that our commonwealth would help because sheltering poor children fleeing unspeakable violence was, to me, an act of patriotism. America has given sanctuary to desperate children for more than a century.',
#    'labels': [{'relevance': 0.33077722787857056,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.01875212788581848,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.003201895859092474,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.0015328740701079369,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.001050358870998025,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.0006913692341186106,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0005417128559201956, 'label': 'Travel>TravelType>Camping'},
#     {'relevance': 0.0005161446169950068,
#      'label': 'Travel>TravelLocations>PolarTravel'},
#     {'relevance': 0.0003803530998993665,
#      'label': 'Travel>TravelLocations>AfricaTravel'},
#     {'relevance': 0.00033826049184426665,
#      'label': 'BusinessAndFinance>Industries>Non-ProfitOrganizations'}],
#    'timestamp': {'start': 578604, 'end': 611304},
#    'sentences_idx_start': 65,
#    'sentences_idx_end': 68},
#   {'text': 'We rescued irish children from famine, russian and ukrainian children from religious persecution, cambodian children from genocide, haitian children from earthquakes, sudanese children from civil war, our own New Orleans children from Hurricane Katrina. Once, in 1939, we turned our backs on jewish children fleeing the nazis. And it remains a blight on our national reputation, as I fear the separation of children in the last administration will be remembered.',
#    'labels': [{'relevance': 0.877464771270752,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.3958105742931366,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.06460115313529968,
#      'label': 'Education>EarlyChildhoodEducation'},
#     {'relevance': 0.03129217401146889,
#      'label': 'FamilyAndRelationships>Parenting>DaycareAndPre-School'},
#     {'relevance': 0.02492254227399826,
#      'label': "HealthyLiving>Children'sHealth"},
#     {'relevance': 0.006162768229842186,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.00542921107262373,
#      'label': 'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11'},
#     {'relevance': 0.005327318795025349,
#      'label': 'Movies>FamilyAndChildrenMovies'},
#     {'relevance': 0.003504802007228136,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.002694361377507448,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'}],
#    'timestamp': {'start': 611844, 'end': 643306},
#    'sentences_idx_start': 69,
#    'sentences_idx_end': 71},
#   {'text': "The point is that our esteem and our power is enhanced when we rescue the desperate and diminished, when we don't still, I'm not naive. I knew my decision would be controversial. And indeed, for that decision, I was called on hate radio and in social media. Everything but a child of God.",
#    'labels': [{'relevance': 0.08244963735342026,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.014275779947638512,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.007985769771039486,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.006124844774603844, 'label': 'NewsAndPolitics'},
#     {'relevance': 0.0051077501848340034,
#      'label': 'Technology&Computing>Computing>Internet>SocialNetworking'},
#     {'relevance': 0.003716671373695135,
#      'label': 'BusinessAndFinance>Industries>Non-ProfitOrganizations'},
#     {'relevance': 0.003026918275281787,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.0023512733168900013,
#      'label': 'BooksAndLiterature>Biographies'},
#     {'relevance': 0.0021811414044350386,
#      'label': 'Hobbies&Interests>ContentProduction>FreelanceWriting'},
#     {'relevance': 0.0020744253415614367,
#      'label': 'MedicalHealth>DiseasesAndConditions>Injuries>FirstAid'}],
#    'timestamp': {'start': 643490, 'end': 662134},
#    'sentences_idx_start': 72,
#    'sentences_idx_end': 75},
#   {'text': "A couple of days after I announced my decision on an unusually quiet Saturday morning, my wife Diane gave me a list of stuff to go get at the Home Depot, proving for some of you who know her that there is no office high enough that excuses you from one of her honey do lists. It was early in the day, and I thought I'd just slip out quickly on my own without bothering my security detail. What harm could come of that, right?",
#    'labels': [{'relevance': 0.9895914196968079,
#      'label': 'Home&Garden>HomeImprovement'},
#     {'relevance': 0.021951040253043175, 'label': 'Home&Garden'},
#     {'relevance': 0.012838256545364857, 'label': 'Home&Garden>HomeAppliances'},
#     {'relevance': 0.012333271093666553, 'label': 'RealEstate>Houses'},
#     {'relevance': 0.007527640555053949, 'label': 'Travel>TravelType>Camping'},
#     {'relevance': 0.006297559943050146,
#      'label': 'Home&Garden>Remodeling&Construction'},
#     {'relevance': 0.004945462569594383,
#      'label': 'Home&Garden>InteriorDecorating'},
#     {'relevance': 0.0032909316942095757, 'label': 'Home&Garden>SmartHome'},
#     {'relevance': 0.002254783408716321, 'label': 'PopCulture>CelebrityHomes'},
#     {'relevance': 0.0020571767818182707,
#      'label': 'Shopping>HouseholdSupplies'}],
#    'timestamp': {'start': 663434, 'end': 690664},
#    'sentences_idx_start': 76,
#    'sentences_idx_end': 78},
#   {'text': "I knew exactly where I was going and where to find everything on my list. So I set off in the truck in a t shirt and jeans and flip flops, dark glasses and a baseball cap, and it didn't matter. I was outed by the manager in the very first aisle. Good morning, governor. Welcome to the Home Depot. How can I help you? I encountered a man in the checkout line who was red hot mad.",
#    'labels': [{'relevance': 0.6369667649269104,
#      'label': 'Home&Garden>HomeImprovement'},
#     {'relevance': 0.06394369155168533, 'label': 'Shopping>GroceryShopping'},
#     {'relevance': 0.014701540581882, 'label': 'Home&Garden>HomeAppliances'},
#     {'relevance': 0.01439235731959343, 'label': 'Shopping'},
#     {'relevance': 0.005576354451477528, 'label': 'Shopping>HouseholdSupplies'},
#     {'relevance': 0.002185215475037694,
#      'label': 'EventsAndAttractions>Malls&ShoppingCenters'},
#     {'relevance': 0.0012857700930908322,
#      'label': 'Automotive>AutoBuyingAndSelling'},
#     {'relevance': 0.0011276529403403401, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.0010915606981143355,
#      'label': 'Home&Garden>Remodeling&Construction'},
#     {'relevance': 0.000948792090639472, 'label': 'PopCulture>CelebrityHomes'}],
#    'timestamp': {'start': 691324, 'end': 717484},
#    'sentences_idx_start': 79,
#    'sentences_idx_end': 85},
#   {'text': "You know, not hostile or threatening, really angry and loud. And he let me have it. Governor said, I couldn't disagree with you more about your decision. He said, my own wife is an immigrant. She came here legally. That's the way it ought to be. And I just want you to know I think you're wrong. Now, in that circumstance, there was no point in trying to engage with him about how being a refugee is legal under american law.",
#    'labels': [{'relevance': 0.007801915984600782,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.003465627785772085,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.0021958076395094395,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.0019295774400234222,
#      'label': 'FamilyAndRelationships>MarriageAndCivilUnions'},
#     {'relevance': 0.001582818222232163,
#      'label': 'Hobbies&Interests>GenealogyAndAncestry'},
#     {'relevance': 0.0015717691276222467, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0005313108558766544,
#      'label': 'PersonalFinance>PersonalTaxes'},
#     {'relevance': 0.0004846076772082597, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.0004384192288853228,
#      'label': 'Travel>TravelLocations>AustraliaAndOceaniaTravel'},
#     {'relevance': 0.00029245964833535254,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'}],
#    'timestamp': {'start': 717904, 'end': 745326},
#    'sentences_idx_start': 86,
#    'sentences_idx_end': 93},
#   {'text': "I just thanked him for his feedback. But everybody in the checkout line and in that area of the story knew who was mad at whom and what he was mad about. Now, I had six other encounters in the store on the same subject. And in every one of those, someone came up and whispered, governor, you're doing the right thing. Governor, thanks for looking out for those kids. Governor, I'm with you.",
#    'labels': [{'relevance': 0.019638748839497566,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.01691087894141674, 'label': 'Shopping>GroceryShopping'},
#     {'relevance': 0.0044114659540355206, 'label': 'NewsAndPolitics'},
#     {'relevance': 0.0041358391754329205, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.003130784025415778, 'label': 'Shopping'},
#     {'relevance': 0.002186911879107356,
#      'label': 'BusinessAndFinance>Business>ConsumerIssues'},
#     {'relevance': 0.002142125740647316, 'label': 'Education>HomeworkAndStudy'},
#     {'relevance': 0.001727878930978477,
#      'label': 'MusicAndAudio>TalkRadio>EducationalRadio'},
#     {'relevance': 0.001669983728788793,
#      'label': 'Education>EarlyChildhoodEducation'},
#     {'relevance': 0.0012972288532182574,
#      'label': 'BusinessAndFinance>Business>ConsumerIssues>Recalls'}],
#    'timestamp': {'start': 745510, 'end': 775634},
#    'sentences_idx_start': 94,
#    'sentences_idx_end': 99},
#   {'text': "The calls to the office were two and three to one in favor of sheltering those children. And when I reflect on that, I think to myself, when did we learn to shout our anger and to whisper our kindness? It's completely upside down. I don't know if that's the reality tv culture we live in or what, but it's too totally backwards. It's time we learned again to shout kindness, to shout compassion, to shout justice.",
#    'labels': [{'relevance': 0.7151538133621216,
#      'label': 'Television>RealityTV'},
#     {'relevance': 0.12503373622894287, 'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.045528706163167953, 'label': 'Television>FactualTV'},
#     {'relevance': 0.043686337769031525,
#      'label': 'FamilyAndRelationships>Parenting>AdoptionAndFostering'},
#     {'relevance': 0.015613073483109474,
#      'label': 'FamilyAndRelationships>Parenting'},
#     {'relevance': 0.010187249630689621,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.006559527944773436,
#      'label': 'PopCulture>CelebrityFamilies'},
#     {'relevance': 0.005955815315246582, 'label': "Television>Children'sTV"},
#     {'relevance': 0.004006463102996349,
#      'label': 'FamilyAndRelationships>SingleLife'},
#     {'relevance': 0.003118121065199375,
#      'label': 'PopCulture>CelebrityRelationships'}],
#    'timestamp': {'start': 776414, 'end': 810768},
#    'sentences_idx_start': 100,
#    'sentences_idx_end': 104},
#   {'text': "That's the purpose of american democracy and the source of our greatness. Blessedly, we're starting to see more and more expressions of this kind of thing across this country. More and more people coming off the sidelines, overcoming their cynicism and fatalism and standing up for America at her generous and optimistic best. From women who are demanding to be treated with the respect and decency everyone deserves. From survivors of domestic violence and abuse, demanding to be seen and heard and believed.",
#    'labels': [{'relevance': 0.9379892945289612,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9372739791870117,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.6850988864898682, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.14115694165229797,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0074823410250246525, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.006807456724345684,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.004101863130927086,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.003241937840357423,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.0017190432408824563, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0014939542161300778,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'}],
#    'timestamp': {'start': 810936, 'end': 848754},
#    'sentences_idx_start': 105,
#    'sentences_idx_end': 109},
#   {'text': "From black and brown people who are demanding consistent professionalism and the presumption of innocence. From police. From students who are demanding we choose their lives and safety over the proliferation of military weapons in civilian hands. From all those lawyers who showed up at polling places in 2020 or at airports after the so called muslim ban, demanding respect for the rule of law. Black lives matter. Time's up. Black girl magic. Occupy Wall street families belong together. At any given time, on any given issue.",
#    'labels': [{'relevance': 0.31079885363578796,
#      'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.04614873602986336,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.013620834797620773,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.0106804883107543,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.00880837719887495,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.007642561104148626,
#      'label': 'PopCulture>CelebrityScandal'},
#     {'relevance': 0.005074284505099058, 'label': 'Food&Drink>FoodMovements'},
#     {'relevance': 0.0037675180938094854, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.0030356755014508963,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.002139891730621457,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'}],
#    'timestamp': {'start': 849374, 'end': 890984},
#    'sentences_idx_start': 110,
#    'sentences_idx_end': 118},
#   {'text': 'They may make any one of us uncomfortable, but they have taken to the legislatures, to the ballot boxes, to the courtrooms, and peacefully to the streets to lay claim to their democracy, its purpose as well as its processes, and ultimately, to affirm the american conscience. They are shouting kindness. If american style democracy is to have a chance, more of us had better put our own cynicism down, summon up our own patriotism and join them. Thank you very much.',
#    'labels': [{'relevance': 0.9637465476989746,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.9558345079421997,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.9425167441368103, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.147858127951622,
#      'label': 'NewsAndPolitics>Politics>Elections'},
#     {'relevance': 0.0004171467153355479, 'label': 'NewsAndPolitics>Law'},
#     {'relevance': 0.0002820066292770207,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.00019903674547094852,
#      'label': 'Technology&Computing>Computing>Internet>InternetForBeginners'},
#     {'relevance': 0.00017591306823305786,
#      'label': 'Automotive>AutoBodyStyles>Microcar'},
#     {'relevance': 0.00017366796964779496,
#      'label': "HealthyLiving>Women'sHealth"},
#     {'relevance': 0.00014407839626073837,
#      'label': 'Hobbies&Interests>GamesAndPuzzles>RoleplayingGames'}],
#    'timestamp': {'start': 891444, 'end': 928734},
#    'sentences_idx_start': 119,
#    'sentences_idx_end': 122}],
#  'summary': {'EventsAndAttractions>PoliticalEvent': 1.0,
#   'NewsAndPolitics>Politics>PoliticalIssues': 0.8536341786384583,
#   'NewsAndPolitics>Politics': 0.8001156449317932,
#   'NewsAndPolitics>Politics>Elections': 0.26783692836761475,
#   'NewsAndPolitics>Crime': 0.2527463436126709,
#   'Home&Garden>HomeImprovement': 0.19234398007392883,
#   'FamilyAndRelationships>Parenting>AdoptionAndFostering': 0.15178827941417694,
#   'NewsAndPolitics>Law': 0.10496598482131958,
#   'Television>RealityTV': 0.08490221947431564,
#   'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare': 0.05182255059480667,
#   'FamilyAndRelationships>Parenting': 0.05133328214287758,
#   'PopCulture>CelebrityScandal': 0.028794826939702034,
#   'NewsAndPolitics>Politics>WarAndConflicts': 0.0171405840665102,
#   'Shopping>GroceryShopping': 0.009660312905907631,
#   'Education>EarlyChildhoodEducation': 0.008355177007615566,
#   'HealthyLiving>FitnessAndExercise>ParticipantSports': 0.006075866520404816,
#   'Television>FactualTV': 0.005588793195784092,
#   'FamilyAndRelationships>SingleLife': 0.005375334527343512,
#   'MedicalHealth>DiseasesAndConditions>ReproductiveHealth': 0.005345528945326805,
#   'Travel>TravelLocations>AfricaTravel': 0.004588071722537279}}

# %%
result_df = pd.DataFrame(columns = ["Text_ID", "Text", "Topic_Label", "Relevance"])

for idx, result in enumerate(results['iab_categories_result']['results']):
    for label in result['labels']:
        
        temp_list = []
        temp_list.append(idx+1)
        temp_list.append(result['text'])
        temp_list.append(label['label'])
        temp_list.append(round(label['relevance'], 2))

        result_df.loc[result_df.shape[0]] = temp_list

result_df.head()
# Out:
#    Text_ID                                               Text  \
# 0        1  Listen, I'm worried about our democracy. Nowad...
# 1        1  Listen, I'm worried about our democracy. Nowad...
# 2        1  Listen, I'm worried about our democracy. Nowad...
# 3        1  Listen, I'm worried about our democracy. Nowad...
# 4        1  Listen, I'm worried about our democracy. Nowad...
#
#                                 Topic_Label  Relevance
# 0  NewsAndPolitics>Politics>PoliticalIssues       0.93
# 1       EventsAndAttractions>PoliticalEvent       0.91
# 2        NewsAndPolitics>Politics>Elections       0.90
# 3                  NewsAndPolitics>Politics       0.78
# 4                       NewsAndPolitics>Law       0.00

# %%
summary_df = pd.DataFrame(columns = ["Label_ID", "Topic_Label", "Relevance"])

for idx, (key, value) in enumerate(results['iab_categories_result']['summary'].items()):

    summary_df.loc[summary_df.shape[0]] = [idx+1, key, round(value, 2)]

summary_df.head()
# Out:
#    Label_ID                               Topic_Label  Relevance
# 0         1       EventsAndAttractions>PoliticalEvent       1.00
# 1         2  NewsAndPolitics>Politics>PoliticalIssues       0.85
# 2         3                  NewsAndPolitics>Politics       0.80
# 3         4        NewsAndPolitics>Politics>Elections       0.27
# 4         5                     NewsAndPolitics>Crime       0.25

# %%
result_df.value_counts("Topic_Label")
# Out:
# Topic_Label
# EventsAndAttractions>PoliticalEvent         18
# NewsAndPolitics>Politics>PoliticalIssues    18
# NewsAndPolitics>Politics                    16
# NewsAndPolitics>Politics>WarAndConflicts    15
# NewsAndPolitics>Politics>Elections          13
#                                             ..
# Automotive>AutoBuyingAndSelling              1
# MusicAndAudio>HipHopMusic                    1
# MusicAndAudio>TalkRadio>EducationalRadio     1
# MusicAndAudio>UrbanContemporaryMusic         1
# Movies>FamilyAndChildrenMovies               1
# Name: count, Length: 91, dtype: int64

# %%
print(summary_df.nlargest(3, "Relevance"))
# Out:
#    Label_ID                               Topic_Label  Relevance
# 0         1       EventsAndAttractions>PoliticalEvent       1.00
# 1         2  NewsAndPolitics>Politics>PoliticalIssues       0.85
# 2         3                  NewsAndPolitics>Politics       0.80
